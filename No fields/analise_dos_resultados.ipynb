# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from scipy.stats import pearsonr

import random
import torch as tc

# %%
N = 50
for std in [0,0.02,0.04,0.06,0.08,0.1]:
    # Inicializando listas para armazenar os erros acumulados
    erros_abs_acumulados = []

    # Loop para carregar os arquivos e calcular os erros
    for i in range(5, 101):
        caminho = f"C:/Users/gubio/Pesquisa/PINN for open quantum system/No fields/data/parametro_nofields_N{N}_seed{i}_std{std}.csv"

        df = pd.read_csv(caminho, index_col=0)
        
        # Calculando erros
        valor_real = df['treino'].str.strip('[]').astype(float)
        valor_previsto = df['previsto'].str.strip('[]').astype(float)
        
        erro_abs = np.abs(valor_real - valor_previsto)/abs(valor_real) # MAPE
        
        # Removendo Js0 e Js1
        #erro_abs = erro_abs.drop(index=['JIX', 'JIY','JIZ','JXI','JYI','JZI'], errors='ignore')
        
        # Acumulando erros
        erros_abs_acumulados.append(erro_abs)

    # Calculando a média, desvio padrão, máximo e mínimo dos erros
    erros_abs_concat = pd.concat(erros_abs_acumulados, axis=1)
    
    tabela_erros = pd.DataFrame({
        "MAPE": abs(erros_abs_concat.mean(axis=1)),
        "Desvio Padrão": erros_abs_concat.std(axis=1),
        "Máximo": erros_abs_concat.max(axis=1),
        "Mínimo": erros_abs_concat.min(axis=1)
    })

    print(tabela_erros)
    
    # Calculando as barras de erro
    yerr = [tabela_erros['MAPE'] - tabela_erros['Mínimo'], 
        tabela_erros['Máximo'] - tabela_erros['MAPE']]

    # Plotando o gráfico de pontos com barras de erro em escala logarítmica
    #plt.figure(figsize=(10, 6))
    plt.title("Std = " + str(std))
    names = [r'$\gamma_1$', r'$\gamma_2$', r'$\gamma_3$', r'$\gamma_4$',
             r'$JXX$',r'$JXY$',r'$JXZ$',r'$JYX$',r'$JYY$',r'$JYZ$',r'$JZX$',
             r'$JZY$',r'$JZZ$']
    plt.errorbar(names, tabela_erros['MAPE'], yerr=yerr, fmt='o', capsize=5)
    plt.yscale('log')
    plt.xlabel('Parâmetros', fontsize=14)
    plt.ylabel('Valores', fontsize=14)
    plt.yticks(fontsize=14)
    #plt.ylim(1e-7, 1e-3)  # Definindo os limites do eixo y
    plt.grid(True)
    plt.show()
# Out:
#             MAPE  Desvio Padrão    Máximo        Mínimo
# gamma1  0.000374       0.000762  0.005236  1.025879e-06
# gamma2  0.000611       0.001214  0.006673  3.405307e-07
# gamma3  0.000403       0.000818  0.005571  2.716539e-06
# gamma4  0.000422       0.000632  0.003535  2.032948e-06
# JXX     0.001328       0.005760  0.055211  1.545651e-06
# JXY     0.000989       0.002878  0.024060  8.400589e-07
# JXZ     0.000431       0.000800  0.005352  2.043514e-08
# JYX     0.000645       0.001129  0.005961  3.964250e-06
# JYY     0.000818       0.002255  0.018666  2.784579e-06
# JYZ     0.000904       0.002618  0.018184  3.151759e-06
# JZX     0.001177       0.004983  0.046729  1.923513e-07
# JZY     0.000916       0.002326  0.017177  3.238805e-07
# JZZ     0.000564       0.001181  0.008669  1.347084e-07
#             MAPE  Desvio Padrão     Máximo    Mínimo
# gamma1  0.027397       0.035289   0.213857  0.000136
# gamma2  0.078897       0.363247   3.565598  0.000152
# gamma3  0.024295       0.032686   0.250278  0.000520
# gamma4  0.034503       0.040421   0.207936  0.000590
# JXX     0.162239       0.480254   3.300491  0.000600
# JXY     0.151596       0.555215   5.148926  0.001243
# JXZ     0.048009       0.073710   0.477323  0.001844
# JYX     0.071663       0.148127   1.113206  0.000427
# JYY     0.117591       0.428611   3.734786  0.000408
# JYZ     0.148740       0.488760   3.927403  0.000488
# JZX     0.087345       0.264668   2.348097  0.001180
# JZY     0.198238       1.224832  11.971443  0.000957
# JZZ     0.096141       0.276268   1.574991  0.001210
#             MAPE  Desvio Padrão     Máximo    Mínimo
# gamma1  0.056630       0.074226   0.447193  0.000192
# gamma2  0.158314       0.720129   7.064913  0.000683
# gamma3  0.048383       0.066001   0.513160  0.000320
# gamma4  0.072116       0.083402   0.438336  0.000855
# JXX     0.336862       1.014949   6.912677  0.001353
# JXY     0.301435       1.092933  10.106005  0.001175
# JXZ     0.096439       0.148452   0.923049  0.000597
# JYX     0.145318       0.300854   2.109474  0.001572
# JYY     0.250821       0.958520   8.547809  0.001520
# JYZ     0.292146       0.960190   7.722843  0.001119
# JZX     0.174336       0.517636   4.561955  0.001687
# JZY     0.400217       2.505485  24.506289  0.000933
# JZZ     0.191347       0.542869   3.131987  0.000785
#             MAPE  Desvio Padrão     Máximo    Mínimo
# gamma1  0.089016       0.118364   0.702178  0.000495
# gamma2  0.241027       1.071271  10.509963  0.001905
# gamma3  0.073612       0.100454   0.777599  0.000078
# gamma4  0.113702       0.132546   0.689118  0.001410
# JXX     0.521661       1.581016  10.486007  0.002340
# JXY     0.444954       1.551623  14.135146  0.003544
# JXZ     0.144500       0.224195   1.347798  0.002665
# JYX     0.224227       0.466750   3.024745  0.003508
# JYY     0.404428       1.609404  14.693412  0.001736
# JYZ     0.433202       1.434573  11.557775  0.000065
# JZX     0.265973       0.776644   6.780007  0.000937
# JZY     0.596532       3.723305  36.419914  0.000411
# JZZ     0.292335       0.823933   4.853174  0.000359
#             MAPE  Desvio Padrão     Máximo    Mínimo
# gamma1  0.124345       0.169050   0.991255  0.000665
# gamma2  0.326828       1.393311  13.668005  0.000745
# gamma3  0.100229       0.136324   1.052255  0.002142
# gamma4  0.162033       0.190090   1.003055  0.001100
# JXX     0.718924       2.174464  13.816983  0.004106
# JXY     0.571798       1.857405  16.344646  0.001771
# JXZ     0.192372       0.302385   1.740763  0.002391
# JYX     0.307881       0.659713   4.195915  0.001466
# JYY     0.573785       2.401356  22.380581  0.000070
# JYZ     0.576186       1.890578  15.160401  0.000642
# JZX     0.357966       1.035676   8.896416  0.000992
# JZY     0.773987       4.745573  46.404118  0.001792
# JZZ     0.397947       1.097959   6.400922  0.012088
#             MAPE  Desvio Padrão     Máximo    Mínimo
# gamma1  0.161255       0.222007   1.292212  0.001350
# gamma2  0.416042       1.698397  16.658019  0.002466
# gamma3  0.128758       0.172842   1.326854  0.001033
# gamma4  0.218781       0.255181   1.553335  0.005945
# JXX     0.929636       2.806591  18.408738  0.002447
# JXY     0.686272       2.018514  16.518737  0.002550
# JXZ     0.236396       0.380083   2.127194  0.004665
# JYX     0.400206       0.886133   6.234631  0.001375
# JYY     0.768494       3.360787  31.702856  0.002542
# JYZ     0.720230       2.351091  18.949901  0.000965
# JZX     0.446922       1.280439  10.869539  0.002340
# JZY     0.934294       5.597383  54.689332  0.002455
# JZZ     0.512839       1.400876   8.211427  0.003755

# %%
# Inicializando listas para armazenar os erros acumulados para cada parâmetro
erros_abs_acumulados_por_parametro = {j: [] for j in ['gamma1', 'gamma2', 'gamma3', 'gamma4']}
N = 50
for std in [0,0.02,0.04,0.06,0.08,0.1]:
    # Loop para carregar os arquivos e calcular os erros
    for i in range(1, 101):
        caminho = f"C:/Users/gubio/Pesquisa/PINN for open quantum system/No fields/data/parametro_nofields_N{N}_seed{i}_std{std}.csv"
        df = pd.read_csv(caminho, index_col=0)
        
        # Calculando erros
        valor_real = df['treino'].str.strip('[]').astype(float)
        valor_previsto = df['previsto'].str.strip('[]').astype(float)
        
        erro_abs = np.abs(valor_real - valor_previsto)/valor_real # MAPE
        
        # Removendo Js0 e Js1
        erro_abs = erro_abs.drop(index=['JXX','JXY', 'JXZ', 'JYX', 'JYY', 'JYZ', 'JZX', 'JZY', 'JZZ'], errors='ignore')
        
        # Acumulando erros por parâmetro
        for j in erros_abs_acumulados_por_parametro.keys():
            if j in erro_abs.index:
                erros_abs_acumulados_por_parametro[j].append((std, erro_abs[j]))

fig, axs = plt.subplots(1, 4, figsize=(25, 6), sharey=True)

for ax, (j, valores) in zip(axs, erros_abs_acumulados_por_parametro.items()):
    valores_df = pd.DataFrame(valores, columns=['std', 'Erro'])
    
    # Calculando a média, mínimo e máximo
    media = valores_df.groupby('std')['Erro'].mean()
    minimo = valores_df.groupby('std')['Erro'].min()
    maximo = valores_df.groupby('std')['Erro'].max()
    
    # Calculando as barras de erro
    yerr = [media - minimo, maximo - media]
    
    ax.errorbar(media.index, media, yerr=yerr, fmt='ko', capsize=5)
    ax.set_title(f"Gráfico de Erro para {j}")
    ax.set_xlabel('std', fontsize=16)
    ax.set_yscale('log')
    ax.grid(True)

axs[0].set_ylabel('Erro', fontsize=16)
plt.show()

# %%
# Inicializando listas para armazenar os erros acumulados para cada parâmetro
erros_abs_acumulados_por_parametro = {j: [] for j in ['JXX','JXY', 'JXZ', 'JYX', 'JYY', 'JYZ', 'JZX', 'JZY', 'JZZ']}
N = 50
for std in [0,0.02,0.04,0.06,0.08,0.1]:
    # Loop para carregar os arquivos e calcular os erros
    for i in range(1, 101):
        caminho = f"C:/Users/gubio/Pesquisa/PINN for open quantum system/No fields/data/parametro_nofields_N{N}_seed{i}_std{std}.csv"
        df = pd.read_csv(caminho, index_col=0)
        
        # Calculando erros
        valor_real = df['treino'].str.strip('[]').astype(float)
        valor_previsto = df['previsto'].str.strip('[]').astype(float)
        
        erro_abs = np.abs(valor_real - valor_previsto)/abs(valor_real) # MAPE
        
        # Removendo Js0 e Js1
        erro_abs = erro_abs.drop(index=['gamma1', 'gamma2', 'gamma3', 'gamma4'], errors='ignore')
        
        # Acumulando erros por parâmetro
        for j in erros_abs_acumulados_por_parametro.keys():
            if j in erro_abs.index:
                erros_abs_acumulados_por_parametro[j].append((std, erro_abs[j]))

fig, axs = plt.subplots(1, 9, figsize=(30, 6), sharey=True)

for ax, (j, valores) in zip(axs, erros_abs_acumulados_por_parametro.items()):
    valores_df = pd.DataFrame(valores, columns=['std', 'Erro'])
    
    # Calculando a média, mínimo e máximo
    media = valores_df.groupby('std')['Erro'].mean()
    minimo = valores_df.groupby('std')['Erro'].min()
    maximo = valores_df.groupby('std')['Erro'].max()
    
    # Calculando as barras de erro
    yerr = [media - minimo, maximo - media]
    
    ax.errorbar(media.index, media, yerr=yerr, fmt='ko', capsize=5)
    ax.set_title(f"Gráfico de Erro para {j}")
    ax.set_xlabel('std', fontsize=16)
    ax.set_yscale('log')
    ax.grid(True)

axs[0].set_ylabel('Erro', fontsize=16)
plt.show()
